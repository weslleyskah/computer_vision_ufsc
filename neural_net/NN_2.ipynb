# %% [markdown]
# ##Importando dataset

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("bhavikjikadara/dog-and-cat-classification-dataset")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'dog-and-cat-classification-dataset' dataset.
# Path to dataset files: /kaggle/input/dog-and-cat-classification-dataset

# %% [markdown]
# ##Analisando dataset

# %%
import os

data_dir = os.path.join(path, 'PetImages')
dog_path = os.path.join(data_dir, 'Dog')
cat_path = os.path.join(data_dir, 'Cat')

len(os.listdir(dog_path))

dog_imgs = os.listdir(dog_path)
cat_imgs = os.listdir(cat_path)

dog_imgs = [os.path.join(dog_path, img) for img in dog_imgs]
cat_imgs = [os.path.join(cat_path, img) for img in cat_imgs]

print(cat_imgs[:5])
# Out:
# ['/kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/7981.jpg', '/kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/6234.jpg', '/kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/1269.jpg', '/kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/3863.jpg', '/kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/6241.jpg']

# %% [markdown]
# ##Separando Dataset

# %%
import tensorflow as tf
from tensorflow import keras

train_ds, val_ds = keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    image_size=(128,128),
    seed=123,
    subset='both',
    batch_size=32
)

classes_names = train_ds.class_names
print(classes_names)
# Out:
# Found 24998 files belonging to 2 classes.
# Using 19999 files for training.
# Using 4999 files for validation.
# ['Cat', 'Dog']

# %% [markdown]
# ## Criando Modelo

# %%
models.Sequential([
    layers.Input(shape=(128,128,3)), # 128x128 rgb
    layers.Rescaling(1/255.0), # normalizar cada pixel [0...1]
    layers.Conv2D(16,3,padding='same', activation='relu'),
])
